# %% [markdown]
# # The Battle of the Neighborhoods - Week 2

# %% [markdown]
# # Introduction / Business Problem

# %% [markdown]
# # Problem Background

# %% [markdown]
# #### The City of Lahore, is the most populous city in the Lahore. Lahore is a city with an extremely rich food culture. People from Lahore are famous all over the country for their love for food. The city offers a vast variety of options when it comes to gastronomy. In recent times, the style of food has achieved popularity in a number of different countries, because of its palatable and milder taste, mainly through the Pakistani diaspora. Moreover, there are many young people from lahore who visit Canada or some foreign countries for higher studies and they oftenly miss their home taste, therefore they face many difficulties to find some good food. Mostly people of lahore loves to eat "Daisi Food", Chinese Food and Italian Food. Therefore in this way they can find suitable place to get food easily.
#
# # Solution
#
# #### This also means that the people of Lahore loves food and the best business could be to open a good resturant but food market is highly competitive. So, here i will use foursquare API to find nearest location and find the most suitable resturant/cuisines for those people

# %% [markdown]
# # Data Section
#
# ### I will use the FourSquare API to collect data / locations of restaurants in Toronto, Canada. As this is one of the most famous city of Canada. So many people who visits Canada they want to stay there.

# %%
import numpy as np # library to handle data in a vectorized manner
import time
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json 
import requests 
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe


from geopy.geocoders import Nominatim # convert an address into latitude and longitude values


import folium # map rendering library
from folium import plugins

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

import seaborn as sns

# import k-means from clustering stage
from sklearn.cluster import KMeans

# %%
address = 'Lawrence Ave E, Toronto, Ontario M1R 2Y6, Canada'
geolocator = Nominatim()
location = geolocator.geocode(address, timeout=10)
latitude = location.latitude
longitude = location.longitude
print("Geographical Coordinates of "+address+" are"+' {}, {}'.format(latitude, longitude))
# Out:
# c:\users\talhazafar.wattoo\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Using Nominatim with the default "geopy/1.20.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
# Geographical Coordinates of Lawrence Ave E, Toronto, Ontario M1R 2Y6, Canada are 43.7441072, -79.3008502

# %%
neigh_latitude = latitude
neigh_longitude = longitude

# %%
CLIENT_ID = 'ZxxxxxxxxxxxxxxxxxxxxxxxxxxV' # your Foursquare ID
CLIENT_SECRET = '2xxxxxxxxxxxxxxxxxxxxxxQ' # your Foursquare Secret
VERSION = '2xxxxxxxx0' # Foursquare API version

# %%
LIMIT = 500 # limit of number of venues returned by Foursquare API
radius = 500 # define radius
# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neigh_latitude, 
    neigh_longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=Z3GYOID11DHZR23CXQJDPK5IW1MNDBIQLECJGKZPFJZAYASV&client_secret=2CRHCHEXBQYBGYJKSLDSDFC1O2BM4D1AOMCORB3HVF4WDTVQ&v=20192510&ll=43.7441072,-79.3008502&radius=500&limit=500'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5db6beabd03360002c95cfa9'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Wexford',
#   'headerFullLocation': 'Wexford, Toronto',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 26,
#   'suggestedBounds': {'ne': {'lat': 43.748607204500004,
#     'lng': -79.29463289050862},
#    'sw': {'lat': 43.7396071955, 'lng': -79.30706750949138}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b4cb66cf964a52065bb26e3',
#        'name': 'Shawarma Empire',
#        'location': {'address': '1823 Lawrence Ave. E',
#         'crossStreet': 'at Pharmacy Ave.',
#         'lat': 43.743405300438305,
#         'lng': -79.30364913090075,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.743405300438305,
#           'lng': -79.30364913090075}],
#         'distance': 238,
#         'postalCode': 'M1R 2Y3',
#         'cc': 'CA',
#         'city': 'Scarborough',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1823 Lawrence Ave. E (at Pharmacy Ave.)',
#          'Scarborough ON M1R 2Y3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d115941735',
#          'name': 'Middle Eastern Restaurant',
#          'pluralName': 'Middle Eastern Restaurants',
#          'shortName': 'Middle Eastern',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b4cb66cf964a52065bb26e3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb0f805f964a520c66e3ce3',
#        'name': 'Arz Fine Foods',
#        'location': {'address': '1909 Lawrence Ave E',
#         'lat': 43.74389829414246,
#         'lng': -79.30099567107857,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74389829414246,
#           'lng': -79.30099567107857}],
#         'distance': 26,
#         'postalCode': 'M1R 2Y6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1909 Lawrence Ave E',
#          'Toronto ON M1R 2Y6',
#          'Canada']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb0f805f964a520c66e3ce3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c27cddd9fb5d13a8cab9857',
#        'name': 'Patna Kebab House',
#        'location': {'address': '1885 Lawrence Ave.',
#         'lat': 43.743513095785126,
#         'lng': -79.30163584158643,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.743513095785126,
#           'lng': -79.30163584158643}],
#         'distance': 91,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1885 Lawrence Ave.', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c27cddd9fb5d13a8cab9857-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dd19e051838a75196486487',
#        'name': 'Ghadir Mid-Eastern Grocery',
#        'location': {'address': '1821 Lawrence Ave E',
#         'crossStreet': 'Pharmacy Ave',
#         'lat': 43.74363845933303,
#         'lng': -79.30423348681926,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74363845933303,
#           'lng': -79.30423348681926}],
#         'distance': 277,
#         'postalCode': 'M1R 2Y3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1821 Lawrence Ave E (Pharmacy Ave)',
#          'Toronto ON M1R 2Y3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dd19e051838a75196486487-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dfd66db8877e9c47496666b',
#        'name': "Nasib's Shawarma & Falafel",
#        'location': {'address': '1867 Lawrence Ave. E.',
#         'crossStreet': 'Pharmacy Ave.',
#         'lat': 43.743512,
#         'lng': -79.3023,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.743512,
#           'lng': -79.3023}],
#         'distance': 134,
#         'postalCode': 'M1R 2Y3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1867 Lawrence Ave. E. (Pharmacy Ave.)',
#          'Toronto ON M1R 2Y3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d115941735',
#          'name': 'Middle Eastern Restaurant',
#          'pluralName': 'Middle Eastern Restaurants',
#          'shortName': 'Middle Eastern',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dfd66db8877e9c47496666b-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '500982f0e4b034274e8373e8',
#        'name': 'Naan & Kabob Halal',
#        'location': {'address': '1801 Lawrence Ave East',
#         'lat': 43.74290326259434,
#         'lng': -79.30514824489153,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74290326259434,
#           'lng': -79.30514824489153}],
#         'distance': 370,
#         'postalCode': 'M1R 2X9',
#         'cc': 'CA',
#         'city': 'Scarborough',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1801 Lawrence Ave East',
#          'Scarborough ON M1R 2X9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d115941735',
#          'name': 'Middle Eastern Restaurant',
#          'pluralName': 'Middle Eastern Restaurants',
#          'shortName': 'Middle Eastern',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-500982f0e4b034274e8373e8-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be8b576d837c9b6e2b6a506',
#        'name': 'Makkalchon Korean Restaurant 맛깔촌',
#        'location': {'address': '1979 Lawrence Ave. E',
#         'crossStreet': 'Warden Ave.',
#         'lat': 43.74494499908732,
#         'lng': -79.2964935606234,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74494499908732,
#           'lng': -79.2964935606234}],
#         'distance': 362,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1979 Lawrence Ave. E (Warden Ave.)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'shortName': 'Korean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be8b576d837c9b6e2b6a506-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0f355bf964a5206a6023e3',
#        'name': 'Ibrahim BBQ',
#        'location': {'address': '1967 Lawrence Avenue East',
#         'lat': 43.74447414666509,
#         'lng': -79.2974995139424,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74447414666509,
#           'lng': -79.2974995139424}],
#         'distance': 272,
#         'postalCode': 'M1R 2Z2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1967 Lawrence Avenue East',
#          'Toronto ON M1R 2Z2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d115941735',
#          'name': 'Middle Eastern Restaurant',
#          'pluralName': 'Middle Eastern Restaurants',
#          'shortName': 'Middle Eastern',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b0f355bf964a5206a6023e3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50e76974e4b08b441d502c86',
#        'name': "Big Moe's (Halal)",
#        'location': {'address': '1961 Lawrence Avenue East',
#         'crossStreet': 'Warden Avenue',
#         'lat': 43.744333584450956,
#         'lng': -79.2977313160344,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.744333584450956,
#           'lng': -79.2977313160344}],
#         'distance': 252,
#         'cc': 'CA',
#         'city': 'Scarborough',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1961 Lawrence Avenue East (Warden Avenue)',
#          'Scarborough ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50e76974e4b08b441d502c86-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5269be82498e1cf7de5d5dd4',
#        'name': 'Super Hakka Restaurant',
#        'location': {'address': '1801 Lawrence Ave E',
#         'lat': 43.74289206733354,
#         'lng': -79.30494945617208,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74289206733354,
#           'lng': -79.30494945617208}],
#         'distance': 356,
#         'postalCode': 'M1R 2X7',
#         'cc': 'CA',
#         'country': 'Canada',
#         'formattedAddress': ['1801 Lawrence Ave E', 'M1R 2X7', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5269be82498e1cf7de5d5dd4-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ca8f629b7106dcb070478a5',
#        'name': 'PizzaLand',
#        'location': {'address': '1801 Lawrence Avenue East',
#         'crossStreet': 'Pharmacy',
#         'lat': 43.74294578432365,
#         'lng': -79.30508024882042,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74294578432365,
#           'lng': -79.30508024882042}],
#         'distance': 363,
#         'postalCode': 'M1R 2X9',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1801 Lawrence Avenue East (Pharmacy)',
#          'Toronto ON M1R 2X9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ca8f629b7106dcb070478a5-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c801edbd4e23704cec35188',
#        'name': 'Pizza Pizza',
#        'location': {'address': '1950 LAWRENCE AVENUE EAST',
#         'lat': 43.7447116,
#         'lng': -79.2990406,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.7447116,
#           'lng': -79.2990406}],
#         'distance': 160,
#         'postalCode': 'M1R 2Y7',
#         'cc': 'CA',
#         'city': 'Scarborough',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1950 LAWRENCE AVENUE EAST',
#          'Scarborough ON M1R 2Y7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c801edbd4e23704cec35188-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ec560f5e5fa74ea535e5ce4',
#        'name': 'The Loaded Dog',
#        'location': {'address': '1921 Lawrence Ave. East',
#         'crossStreet': 'Pharmacy',
#         'lat': 43.74427837403965,
#         'lng': -79.29987247913081,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74427837403965,
#           'lng': -79.29987247913081}],
#         'distance': 80,
#         'postalCode': 'M1R 3Y6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1921 Lawrence Ave. East (Pharmacy)',
#          'Toronto ON M1R 3Y6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ec560f5e5fa74ea535e5ce4-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50f9bbcb5d24acebc25931dd',
#        'name': "Domino's Pizza",
#        'location': {'address': '1889 Lawrence Avenue East',
#         'lat': 43.743789595827515,
#         'lng': -79.30148725577797,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.743789595827515,
#           'lng': -79.30148725577797}],
#         'distance': 62,
#         'postalCode': 'M1R 2Y3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1889 Lawrence Avenue East',
#          'Toronto ON M1R 2Y3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50f9bbcb5d24acebc25931dd-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a8b8571e7a237608e0471a6',
#        'name': 'Top Gun Steak & Burgers',
#        'location': {'address': '1960 Lawrence Ave E',
#         'lat': 43.744917,
#         'lng': -79.298242,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.744917,
#           'lng': -79.298242}],
#         'distance': 228,
#         'postalCode': 'M1R 2Z1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1960 Lawrence Ave E',
#          'Toronto ON M1R 2Z1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a8b8571e7a237608e0471a6-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be04f2d2aed2d7f22d4c76f',
#        'name': 'Tim Hortons',
#        'location': {'address': '2044 Lawrence Ave East',
#         'crossStreet': 'Warden Avenue',
#         'lat': 43.7455132382073,
#         'lng': -79.2952139675617,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.7455132382073,
#           'lng': -79.2952139675617}],
#         'distance': 479,
#         'postalCode': 'M1R 2Z3',
#         'cc': 'CA',
#         'city': 'Scarborough',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['2044 Lawrence Ave East (Warden Avenue)',
#          'Scarborough ON M1R 2Z3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be04f2d2aed2d7f22d4c76f-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c58dfd5b05c1b8d0da2d4b1',
#        'name': 'Pioneer',
#        'location': {'address': '1980 Lawrence Ave E',
#         'lat': 43.745063,
#         'lng': -79.297533,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.745063,
#           'lng': -79.297533}],
#         'distance': 287,
#         'postalCode': 'M1R 2Z1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1980 Lawrence Ave E',
#          'Toronto ON M1R 2Z1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d113951735',
#          'name': 'Gas Station',
#          'pluralName': 'Gas Stations',
#          'shortName': 'Gas Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c58dfd5b05c1b8d0da2d4b1-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ac6f597f0b4904f39a967a5',
#        'name': 'Habibiz 2',
#        'location': {'address': '1996 Lawrence ave East',
#         'lat': 43.745293,
#         'lng': -79.29736,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.745293,
#           'lng': -79.29736}],
#         'distance': 310,
#         'postalCode': 'M1R 2Z1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1996 Lawrence ave East',
#          'Toronto ON M1R 2Z1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d119941735',
#          'name': 'Hookah Bar',
#          'pluralName': 'Hookah Bars',
#          'shortName': 'Hookah Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/hookahbar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5ac6f597f0b4904f39a967a5-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b4f70aef964a520ae0627e3',
#        'name': 'Cucina Manila',
#        'location': {'address': '1842 Lawrence Ave. East',
#         'crossStreet': 'Pharmacy Ave.',
#         'lat': 43.74349973548066,
#         'lng': -79.30462952008224,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74349973548066,
#           'lng': -79.30462952008224}],
#         'distance': 311,
#         'cc': 'CA',
#         'city': 'Scarborough',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1842 Lawrence Ave. East (Pharmacy Ave.)',
#          'Scarborough ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b4f70aef964a520ae0627e3-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50a2d4ffe4b08f00eed7cba7',
#        'name': 'Lawrence Ave E & Pharmacy Ave',
#        'location': {'lat': 43.743029014094425,
#         'lng': -79.30453478465827,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.743029014094425,
#           'lng': -79.30453478465827}],
#         'distance': 319,
#         'cc': 'CA',
#         'neighborhood': 'Wexford',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['Toronto ON', 'Canada']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b4c',
#          'name': 'Intersection',
#          'pluralName': 'Intersections',
#          'shortName': 'Intersection',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50a2d4ffe4b08f00eed7cba7-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dac94ba1e72c4e8dcaaf0bb',
#        'name': 'Bus Stop: 54 & 67',
#        'location': {'address': 'Pharmacy & Lawrence E',
#         'lat': 43.74330116517002,
#         'lng': -79.30478910686521,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74330116517002,
#           'lng': -79.30478910686521}],
#         'distance': 329,
#         'cc': 'CA',
#         'city': 'Scarborough',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['Pharmacy & Lawrence E',
#          'Scarborough ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1fe931735',
#          'name': 'Bus Station',
#          'pluralName': 'Bus Stations',
#          'shortName': 'Bus Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dac94ba1e72c4e8dcaaf0bb-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d11422499b78cfa1891c8d5',
#        'name': 'P.A.T. Mart 한국식품',
#        'location': {'address': '1973 Lawrence Ave E',
#         'crossStreet': 'at Wayne Ave',
#         'lat': 43.744904616778435,
#         'lng': -79.29671587467355,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.744904616778435,
#           'lng': -79.29671587467355}],
#         'distance': 344,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1973 Lawrence Ave E (at Wayne Ave)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d11422499b78cfa1891c8d5-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5adbf039f62f2b2ae5378f78',
#        'name': "Kunafa's",
#        'location': {'address': '1801 Lawrence Avenue East\nScarborough, Ontario M1R 2X9',
#         'lat': 43.742542,
#         'lng': -79.30537,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.742542,
#           'lng': -79.30537}],
#         'distance': 403,
#         'postalCode': 'M1R 2X9',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1801 Lawrence Avenue East',
#          'Scarborough, Ontario M1R 2X9',
#          'Toronto ON M1R 2X9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5adbf039f62f2b2ae5378f78-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e0e43f3fa76d62f444738eb',
#        'name': 'Sequoia Lounge',
#        'location': {'address': '2034 Lawrence Ave. E',
#         'lat': 43.74564498729392,
#         'lng': -79.29573737087405,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74564498729392,
#           'lng': -79.29573737087405}],
#         'distance': 445,
#         'postalCode': 'M1R 2Z3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['2034 Lawrence Ave. E',
#          'Toronto ON M1R 2Z3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d115941735',
#          'name': 'Middle Eastern Restaurant',
#          'pluralName': 'Middle Eastern Restaurants',
#          'shortName': 'Middle Eastern',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e0e43f3fa76d62f444738eb-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51ee8639498e5fd21b21be8a',
#        'name': 'My Sonic (Aka HedgeHog)',
#        'location': {'lat': 43.74514076888013,
#         'lng': -79.29517489213902,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74514076888013,
#           'lng': -79.29517489213902}],
#         'distance': 470,
#         'cc': 'CA',
#         'neighborhood': 'Wexford',
#         'country': 'Canada',
#         'formattedAddress': ['Canada']},
#        'categories': [{'id': '4f2a23984b9023bd5841ed2c',
#          'name': 'Moving Target',
#          'pluralName': 'Moving Targets',
#          'shortName': 'Moving Target',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/movingtarget_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51ee8639498e5fd21b21be8a-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4eb28a3a30f8f1e8b97945b9',
#        'name': 'Warden Ave & Lawrence Ave E',
#        'location': {'address': 'Lawrence Avenue East',
#         'crossStreet': 'at Warden Avenue',
#         'lat': 43.74525839874023,
#         'lng': -79.29483917471472,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74525839874023,
#           'lng': -79.29483917471472}],
#         'distance': 500,
#         'cc': 'CA',
#         'neighborhood': 'Wexford',
#         'city': 'Scarborough',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['Lawrence Avenue East (at Warden Avenue)',
#          'Scarborough ON',
#          'Canada']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b4c',
#          'name': 'Intersection',
#          'pluralName': 'Intersections',
#          'shortName': 'Intersection',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4eb28a3a30f8f1e8b97945b9-25'}]}]}}

# %%
venues = results['response']['groups'][0]['items']
normalized_venues = json_normalize(venues)
normalized_venues.head()
# Out:
#    reasons.count                                      reasons.items  \
# 0              0  [{'summary': 'This spot is popular', 'type': '...
# 1              0  [{'summary': 'This spot is popular', 'type': '...
# 2              0  [{'summary': 'This spot is popular', 'type': '...
# 3              0  [{'summary': 'This spot is popular', 'type': '...
# 4              0  [{'summary': 'This spot is popular', 'type': '...
#
#                        referralId  \
# 0  e-0-4b4cb66cf964a52065bb26e3-0
# 1  e-0-4bb0f805f964a520c66e3ce3-1
# 2  e-0-4c27cddd9fb5d13a8cab9857-2
# 3  e-0-4dd19e051838a75196486487-3
# 4  e-0-4dfd66db8877e9c47496666b-4
#
#                                     venue.categories  \
# 0  [{'id': '4bf58dd8d48988d115941735', 'name': 'M...
# 1  [{'id': '52f2ab2ebcbc57f1066b8b46', 'name': 'S...
# 2  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...
# 3  [{'id': '4bf58dd8d48988d118951735', 'name': 'G...
# 4  [{'id': '4bf58dd8d48988d115941735', 'name': 'M...
#
#                    venue.id venue.location.address venue.location.cc  \
# 0  4b4cb66cf964a52065bb26e3   1823 Lawrence Ave. E                CA
# 1  4bb0f805f964a520c66e3ce3    1909 Lawrence Ave E                CA
# 2  4c27cddd9fb5d13a8cab9857     1885 Lawrence Ave.                CA
# 3  4dd19e051838a75196486487    1821 Lawrence Ave E                CA
# 4  4dfd66db8877e9c47496666b  1867 Lawrence Ave. E.                CA
#
#   venue.location.city venue.location.country venue.location.crossStreet  \
# 0         Scarborough                 Canada           at Pharmacy Ave.
# 1             Toronto                 Canada                        NaN
# 2             Toronto                 Canada                        NaN
# 3             Toronto                 Canada               Pharmacy Ave
# 4             Toronto                 Canada              Pharmacy Ave.
#
#    venue.location.distance                    venue.location.formattedAddress  \
# 0                      238  [1823 Lawrence Ave. E (at Pharmacy Ave.), Scar...
# 1                       26  [1909 Lawrence Ave E, Toronto ON M1R 2Y6, Canada]
# 2                       91           [1885 Lawrence Ave., Toronto ON, Canada]
# 3                      277  [1821 Lawrence Ave E (Pharmacy Ave), Toronto O...
# 4                      134  [1867 Lawrence Ave. E. (Pharmacy Ave.), Toront...
#
#                        venue.location.labeledLatLngs  venue.location.lat  \
# 0  [{'label': 'display', 'lat': 43.74340530043830...           43.743405
# 1  [{'label': 'display', 'lat': 43.74389829414246...           43.743898
# 2  [{'label': 'display', 'lat': 43.74351309578512...           43.743513
# 3  [{'label': 'display', 'lat': 43.74363845933303...           43.743638
# 4  [{'label': 'display', 'lat': 43.743512, 'lng':...           43.743512
#
#    venue.location.lng venue.location.neighborhood venue.location.postalCode  \
# 0          -79.303649                         NaN                   M1R 2Y3
# 1          -79.300996                         NaN                   M1R 2Y6
# 2          -79.301636                         NaN                       NaN
# 3          -79.304233                         NaN                   M1R 2Y3
# 4          -79.302300                         NaN                   M1R 2Y3
#
#   venue.location.state                  venue.name  venue.photos.count  \
# 0                   ON             Shawarma Empire                   0
# 1                   ON              Arz Fine Foods                   0
# 2                   ON           Patna Kebab House                   0
# 3                   ON  Ghadir Mid-Eastern Grocery                   0
# 4                   ON  Nasib's Shawarma & Falafel                   0
#
#   venue.photos.groups
# 0                  []
# 1                  []
# 2                  []
# 3                  []
# 4                  []

# %%
filter_columns = ['venue.name', 'venue.location.address', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
normalized_venues.loc[:,filter_columns]
# Out:
#                           venue.name  \
# 0                    Shawarma Empire
# 1                     Arz Fine Foods
# 2                  Patna Kebab House
# 3         Ghadir Mid-Eastern Grocery
# 4         Nasib's Shawarma & Falafel
# 5                 Naan & Kabob Halal
# 6   Makkalchon Korean Restaurant 맛깔촌
# 7                        Ibrahim BBQ
# 8                  Big Moe's (Halal)
# 9             Super Hakka Restaurant
# 10                         PizzaLand
# 11                       Pizza Pizza
# 12                    The Loaded Dog
# 13                    Domino's Pizza
# 14           Top Gun Steak & Burgers
# 15                       Tim Hortons
# 16                           Pioneer
# 17                         Habibiz 2
# 18                     Cucina Manila
# 19     Lawrence Ave E & Pharmacy Ave
# 20                 Bus Stop: 54 & 67
# 21                  P.A.T. Mart 한국식품
# 22                          Kunafa's
# 23                    Sequoia Lounge
# 24           My Sonic (Aka HedgeHog)
# 25       Warden Ave & Lawrence Ave E
#
#                                venue.location.address  \
# 0                                1823 Lawrence Ave. E
# 1                                 1909 Lawrence Ave E
# 2                                  1885 Lawrence Ave.
# 3                                 1821 Lawrence Ave E
# 4                               1867 Lawrence Ave. E.
# 5                              1801 Lawrence Ave East
# 6                                1979 Lawrence Ave. E
# 7                           1967 Lawrence Avenue East
# 8                           1961 Lawrence Avenue East
# 9                                 1801 Lawrence Ave E
# 10                          1801 Lawrence Avenue East
# 11                          1950 LAWRENCE AVENUE EAST
# 12                            1921 Lawrence Ave. East
# 13                          1889 Lawrence Avenue East
# 14                                1960 Lawrence Ave E
# 15                             2044 Lawrence Ave East
# 16                                1980 Lawrence Ave E
# 17                             1996 Lawrence ave East
# 18                            1842 Lawrence Ave. East
# 19                                                NaN
# 20                              Pharmacy & Lawrence E
# 21                                1973 Lawrence Ave E
# 22  1801 Lawrence Avenue East\nScarborough, Ontari...
# 23                               2034 Lawrence Ave. E
# 24                                                NaN
# 25                               Lawrence Avenue East
#
#                                      venue.categories  venue.location.lat  \
# 0   [{'id': '4bf58dd8d48988d115941735', 'name': 'M...           43.743405
# 1   [{'id': '52f2ab2ebcbc57f1066b8b46', 'name': 'S...           43.743898
# 2   [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...           43.743513
# 3   [{'id': '4bf58dd8d48988d118951735', 'name': 'G...           43.743638
# 4   [{'id': '4bf58dd8d48988d115941735', 'name': 'M...           43.743512
# 5   [{'id': '4bf58dd8d48988d115941735', 'name': 'M...           43.742903
# 6   [{'id': '4bf58dd8d48988d113941735', 'name': 'K...           43.744945
# 7   [{'id': '4bf58dd8d48988d115941735', 'name': 'M...           43.744474
# 8   [{'id': '4bf58dd8d48988d16c941735', 'name': 'B...           43.744334
# 9   [{'id': '4bf58dd8d48988d145941735', 'name': 'C...           43.742892
# 10  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...           43.742946
# 11  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...           43.744712
# 12  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...           43.744278
# 13  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...           43.743790
# 14  [{'id': '4bf58dd8d48988d16c941735', 'name': 'B...           43.744917
# 15  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...           43.745513
# 16  [{'id': '4bf58dd8d48988d113951735', 'name': 'G...           43.745063
# 17  [{'id': '4bf58dd8d48988d119941735', 'name': 'H...           43.745293
# 18  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...           43.743500
# 19  [{'id': '52f2ab2ebcbc57f1066b8b4c', 'name': 'I...           43.743029
# 20  [{'id': '4bf58dd8d48988d1fe931735', 'name': 'B...           43.743301
# 21  [{'id': '4bf58dd8d48988d118951735', 'name': 'G...           43.744905
# 22  [{'id': '4bf58dd8d48988d1d0941735', 'name': 'D...           43.742542
# 23  [{'id': '4bf58dd8d48988d115941735', 'name': 'M...           43.745645
# 24  [{'id': '4f2a23984b9023bd5841ed2c', 'name': 'M...           43.745141
# 25  [{'id': '52f2ab2ebcbc57f1066b8b4c', 'name': 'I...           43.745258
#
#     venue.location.lng
# 0           -79.303649
# 1           -79.300996
# 2           -79.301636
# 3           -79.304233
# 4           -79.302300
# 5           -79.305148
# 6           -79.296494
# 7           -79.297500
# 8           -79.297731
# 9           -79.304949
# 10          -79.305080
# 11          -79.299041
# 12          -79.299872
# 13          -79.301487
# 14          -79.298242
# 15          -79.295214
# 16          -79.297533
# 17          -79.297360
# 18          -79.304630
# 19          -79.304535
# 20          -79.304789
# 21          -79.296716
# 22          -79.305370
# 23          -79.295737
# 24          -79.295175
# 25          -79.294839

# %%
normalized_venues['venue.categories'][0][0]['name']
# Out:
# 'Middle Eastern Restaurant'

# %%
def get_categories(results):
    category = results['venue.categories']
    if len(category) == 0:
        return None
    else:
        return category[0]['name']

# %%
normalized_venues['venue.categories'] = normalized_venues.apply(get_categories, axis=1)
normalized_venues.head()
# Out:
#    reasons.count                                      reasons.items  \
# 0              0  [{'summary': 'This spot is popular', 'type': '...
# 1              0  [{'summary': 'This spot is popular', 'type': '...
# 2              0  [{'summary': 'This spot is popular', 'type': '...
# 3              0  [{'summary': 'This spot is popular', 'type': '...
# 4              0  [{'summary': 'This spot is popular', 'type': '...
#
#                        referralId           venue.categories  \
# 0  e-0-4b4cb66cf964a52065bb26e3-0  Middle Eastern Restaurant
# 1  e-0-4bb0f805f964a520c66e3ce3-1                Supermarket
# 2  e-0-4c27cddd9fb5d13a8cab9857-2          Indian Restaurant
# 3  e-0-4dd19e051838a75196486487-3              Grocery Store
# 4  e-0-4dfd66db8877e9c47496666b-4  Middle Eastern Restaurant
#
#                    venue.id venue.location.address venue.location.cc  \
# 0  4b4cb66cf964a52065bb26e3   1823 Lawrence Ave. E                CA
# 1  4bb0f805f964a520c66e3ce3    1909 Lawrence Ave E                CA
# 2  4c27cddd9fb5d13a8cab9857     1885 Lawrence Ave.                CA
# 3  4dd19e051838a75196486487    1821 Lawrence Ave E                CA
# 4  4dfd66db8877e9c47496666b  1867 Lawrence Ave. E.                CA
#
#   venue.location.city venue.location.country venue.location.crossStreet  \
# 0         Scarborough                 Canada           at Pharmacy Ave.
# 1             Toronto                 Canada                        NaN
# 2             Toronto                 Canada                        NaN
# 3             Toronto                 Canada               Pharmacy Ave
# 4             Toronto                 Canada              Pharmacy Ave.
#
#    venue.location.distance                    venue.location.formattedAddress  \
# 0                      238  [1823 Lawrence Ave. E (at Pharmacy Ave.), Scar...
# 1                       26  [1909 Lawrence Ave E, Toronto ON M1R 2Y6, Canada]
# 2                       91           [1885 Lawrence Ave., Toronto ON, Canada]
# 3                      277  [1821 Lawrence Ave E (Pharmacy Ave), Toronto O...
# 4                      134  [1867 Lawrence Ave. E. (Pharmacy Ave.), Toront...
#
#                        venue.location.labeledLatLngs  venue.location.lat  \
# 0  [{'label': 'display', 'lat': 43.74340530043830...           43.743405
# 1  [{'label': 'display', 'lat': 43.74389829414246...           43.743898
# 2  [{'label': 'display', 'lat': 43.74351309578512...           43.743513
# 3  [{'label': 'display', 'lat': 43.74363845933303...           43.743638
# 4  [{'label': 'display', 'lat': 43.743512, 'lng':...           43.743512
#
#    venue.location.lng venue.location.neighborhood venue.location.postalCode  \
# 0          -79.303649                         NaN                   M1R 2Y3
# 1          -79.300996                         NaN                   M1R 2Y6
# 2          -79.301636                         NaN                       NaN
# 3          -79.304233                         NaN                   M1R 2Y3
# 4          -79.302300                         NaN                   M1R 2Y3
#
#   venue.location.state                  venue.name  venue.photos.count  \
# 0                   ON             Shawarma Empire                   0
# 1                   ON              Arz Fine Foods                   0
# 2                   ON           Patna Kebab House                   0
# 3                   ON  Ghadir Mid-Eastern Grocery                   0
# 4                   ON  Nasib's Shawarma & Falafel                   0
#
#   venue.photos.groups
# 0                  []
# 1                  []
# 2                  []
# 3                  []
# 4                  []

# %%
required_details = normalized_venues.loc[:,filter_columns]

# %%
required_details.columns=['Name', 'Address', 'Categories', 'Latitude', 'Longitude']

# %%
required_details
# Out:
#                                 Name  \
# 0                    Shawarma Empire
# 1                     Arz Fine Foods
# 2                  Patna Kebab House
# 3         Ghadir Mid-Eastern Grocery
# 4         Nasib's Shawarma & Falafel
# 5                 Naan & Kabob Halal
# 6   Makkalchon Korean Restaurant 맛깔촌
# 7                        Ibrahim BBQ
# 8                  Big Moe's (Halal)
# 9             Super Hakka Restaurant
# 10                         PizzaLand
# 11                       Pizza Pizza
# 12                    The Loaded Dog
# 13                    Domino's Pizza
# 14           Top Gun Steak & Burgers
# 15                       Tim Hortons
# 16                           Pioneer
# 17                         Habibiz 2
# 18                     Cucina Manila
# 19     Lawrence Ave E & Pharmacy Ave
# 20                 Bus Stop: 54 & 67
# 21                  P.A.T. Mart 한국식품
# 22                          Kunafa's
# 23                    Sequoia Lounge
# 24           My Sonic (Aka HedgeHog)
# 25       Warden Ave & Lawrence Ave E
#
#                                               Address  \
# 0                                1823 Lawrence Ave. E
# 1                                 1909 Lawrence Ave E
# 2                                  1885 Lawrence Ave.
# 3                                 1821 Lawrence Ave E
# 4                               1867 Lawrence Ave. E.
# 5                              1801 Lawrence Ave East
# 6                                1979 Lawrence Ave. E
# 7                           1967 Lawrence Avenue East
# 8                           1961 Lawrence Avenue East
# 9                                 1801 Lawrence Ave E
# 10                          1801 Lawrence Avenue East
# 11                          1950 LAWRENCE AVENUE EAST
# 12                            1921 Lawrence Ave. East
# 13                          1889 Lawrence Avenue East
# 14                                1960 Lawrence Ave E
# 15                             2044 Lawrence Ave East
# 16                                1980 Lawrence Ave E
# 17                             1996 Lawrence ave East
# 18                            1842 Lawrence Ave. East
# 19                                                NaN
# 20                              Pharmacy & Lawrence E
# 21                                1973 Lawrence Ave E
# 22  1801 Lawrence Avenue East\nScarborough, Ontari...
# 23                               2034 Lawrence Ave. E
# 24                                                NaN
# 25                               Lawrence Avenue East
#
#                    Categories   Latitude  Longitude
# 0   Middle Eastern Restaurant  43.743405 -79.303649
# 1                 Supermarket  43.743898 -79.300996
# 2           Indian Restaurant  43.743513 -79.301636
# 3               Grocery Store  43.743638 -79.304233
# 4   Middle Eastern Restaurant  43.743512 -79.302300
# 5   Middle Eastern Restaurant  43.742903 -79.305148
# 6           Korean Restaurant  43.744945 -79.296494
# 7   Middle Eastern Restaurant  43.744474 -79.297500
# 8                Burger Joint  43.744334 -79.297731
# 9          Chinese Restaurant  43.742892 -79.304949
# 10                Pizza Place  43.742946 -79.305080
# 11                Pizza Place  43.744712 -79.299041
# 12                        Bar  43.744278 -79.299872
# 13                Pizza Place  43.743790 -79.301487
# 14               Burger Joint  43.744917 -79.298242
# 15                Coffee Shop  43.745513 -79.295214
# 16                Gas Station  43.745063 -79.297533
# 17                 Hookah Bar  43.745293 -79.297360
# 18           Asian Restaurant  43.743500 -79.304630
# 19               Intersection  43.743029 -79.304535
# 20                Bus Station  43.743301 -79.304789
# 21              Grocery Store  43.744905 -79.296716
# 22               Dessert Shop  43.742542 -79.305370
# 23  Middle Eastern Restaurant  43.745645 -79.295737
# 24              Moving Target  43.745141 -79.295175
# 25               Intersection  43.745258 -79.294839

# %%
clean_data = required_details

# %%
clean_data = clean_data[clean_data['Address'].notnull()]
clean_data
# Out:
#                                 Name  \
# 0                    Shawarma Empire
# 1                     Arz Fine Foods
# 2                  Patna Kebab House
# 3         Ghadir Mid-Eastern Grocery
# 4         Nasib's Shawarma & Falafel
# 5                 Naan & Kabob Halal
# 6   Makkalchon Korean Restaurant 맛깔촌
# 7                        Ibrahim BBQ
# 8                  Big Moe's (Halal)
# 9             Super Hakka Restaurant
# 10                         PizzaLand
# 11                       Pizza Pizza
# 12                    The Loaded Dog
# 13                    Domino's Pizza
# 14           Top Gun Steak & Burgers
# 15                       Tim Hortons
# 16                           Pioneer
# 17                         Habibiz 2
# 18                     Cucina Manila
# 20                 Bus Stop: 54 & 67
# 21                  P.A.T. Mart 한국식품
# 22                          Kunafa's
# 23                    Sequoia Lounge
# 25       Warden Ave & Lawrence Ave E
#
#                                               Address  \
# 0                                1823 Lawrence Ave. E
# 1                                 1909 Lawrence Ave E
# 2                                  1885 Lawrence Ave.
# 3                                 1821 Lawrence Ave E
# 4                               1867 Lawrence Ave. E.
# 5                              1801 Lawrence Ave East
# 6                                1979 Lawrence Ave. E
# 7                           1967 Lawrence Avenue East
# 8                           1961 Lawrence Avenue East
# 9                                 1801 Lawrence Ave E
# 10                          1801 Lawrence Avenue East
# 11                          1950 LAWRENCE AVENUE EAST
# 12                            1921 Lawrence Ave. East
# 13                          1889 Lawrence Avenue East
# 14                                1960 Lawrence Ave E
# 15                             2044 Lawrence Ave East
# 16                                1980 Lawrence Ave E
# 17                             1996 Lawrence ave East
# 18                            1842 Lawrence Ave. East
# 20                              Pharmacy & Lawrence E
# 21                                1973 Lawrence Ave E
# 22  1801 Lawrence Avenue East\nScarborough, Ontari...
# 23                               2034 Lawrence Ave. E
# 25                               Lawrence Avenue East
#
#                    Categories   Latitude  Longitude
# 0   Middle Eastern Restaurant  43.743405 -79.303649
# 1                 Supermarket  43.743898 -79.300996
# 2           Indian Restaurant  43.743513 -79.301636
# 3               Grocery Store  43.743638 -79.304233
# 4   Middle Eastern Restaurant  43.743512 -79.302300
# 5   Middle Eastern Restaurant  43.742903 -79.305148
# 6           Korean Restaurant  43.744945 -79.296494
# 7   Middle Eastern Restaurant  43.744474 -79.297500
# 8                Burger Joint  43.744334 -79.297731
# 9          Chinese Restaurant  43.742892 -79.304949
# 10                Pizza Place  43.742946 -79.305080
# 11                Pizza Place  43.744712 -79.299041
# 12                        Bar  43.744278 -79.299872
# 13                Pizza Place  43.743790 -79.301487
# 14               Burger Joint  43.744917 -79.298242
# 15                Coffee Shop  43.745513 -79.295214
# 16                Gas Station  43.745063 -79.297533
# 17                 Hookah Bar  43.745293 -79.297360
# 18           Asian Restaurant  43.743500 -79.304630
# 20                Bus Station  43.743301 -79.304789
# 21              Grocery Store  43.744905 -79.296716
# 22               Dessert Shop  43.742542 -79.305370
# 23  Middle Eastern Restaurant  43.745645 -79.295737
# 25               Intersection  43.745258 -79.294839

# %%
map_rest = folium.Map(location=[neigh_latitude, neigh_longitude], zoom_start=18)
# add markers to map
for lat, lng, label in zip(clean_data['Latitude'], clean_data['Longitude'], clean_data['Name']):
    label = folium.Popup(label, parse_html=True)
    folium.RegularPolygonMarker(
        [neigh_latitude, neigh_longitude],
        number_of_sides=30,
        radius=7,
        popup=label,
        color='blue',
        fill_color='#0f0f0f',
        fill_opacity=0.6,
    ).add_to(map_rest)  
    
map_rest
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
clean_data.head()
# Out:
#                          Name                Address  \
# 0             Shawarma Empire   1823 Lawrence Ave. E
# 1              Arz Fine Foods    1909 Lawrence Ave E
# 2           Patna Kebab House     1885 Lawrence Ave.
# 3  Ghadir Mid-Eastern Grocery    1821 Lawrence Ave E
# 4  Nasib's Shawarma & Falafel  1867 Lawrence Ave. E.
#
#                   Categories   Latitude  Longitude
# 0  Middle Eastern Restaurant  43.743405 -79.303649
# 1                Supermarket  43.743898 -79.300996
# 2          Indian Restaurant  43.743513 -79.301636
# 3              Grocery Store  43.743638 -79.304233
# 4  Middle Eastern Restaurant  43.743512 -79.302300

# %% [markdown]
# # DISCUSSION
# ### In general, I am positively impressed with the overall organization, content and lab works presented during the Coursera IBM Certification Course I feel this Capstone project presented me a great opportunity to practice and apply the Data Science tools and methodologies learned.
# ### I have created a good project that I can present as an example to show my potential. I feel I have acquired a good starting point to become a professional Data Scientist and I will continue exploring to creating examples of practical cases.¶

# %% [markdown]
# # Conclusion
# ### The mapping with Folium is a very powerful technique to consolidate information and make the analysis and decision thoroughly and with confidence. I would recommend for use in similar situations.
